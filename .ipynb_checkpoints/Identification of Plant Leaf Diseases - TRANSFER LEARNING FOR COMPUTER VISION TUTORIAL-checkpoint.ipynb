# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

FMD_path = "D:\Kaio_Poc_Telhas\FMD"
images_path = os.path.join(FMD_path, "image")

labels = os.listdir(images_path)
images_metadata = []

for label in labels:
    label_path = os.path.join(images_path, label)
    label_images = [label_file for label_file in os.listdir(label_path) if label_file.endswith(".jpg")]
    
    images_metadata.append({
        "label": label,
        "path": label_path,
        "train": FMD_path + "\\train_val_format\\train\\" + label,
        "val": FMD_path + "\\train_val_format\\val\\" + label,
        "images": label_images
    })
    #images_dict[label] = label_images
    
images_metadata
# Out:
# [{'label': 'fabric',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\fabric',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\fabric',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\fabric',
#   'images': ['fabric_moderate_001_new.jpg',
#    'fabric_moderate_002_new.jpg',
#    'fabric_moderate_003_new.jpg',
#    'fabric_moderate_004_new.jpg',
#    'fabric_moderate_005_new.jpg',
#    'fabric_moderate_006_new.jpg',
#    'fabric_moderate_007_new.jpg',
#    'fabric_moderate_008_new.jpg',
#    'fabric_moderate_009_new.jpg',
#    'fabric_moderate_010_new.jpg',
#    'fabric_moderate_011_new.jpg',
#    'fabric_moderate_012_new.jpg',
#    'fabric_moderate_013_new.jpg',
#    'fabric_moderate_014_new.jpg',
#    'fabric_moderate_015_new.jpg',
#    'fabric_moderate_016_new.jpg',
#    'fabric_moderate_017_new.jpg',
#    'fabric_moderate_018_new.jpg',
#    'fabric_moderate_019_new.jpg',
#    'fabric_moderate_020_new.jpg',
#    'fabric_moderate_021_new.jpg',
#    'fabric_moderate_022_new.jpg',
#    'fabric_moderate_023_new.jpg',
#    'fabric_moderate_024_new.jpg',
#    'fabric_moderate_025_new.jpg',
#    'fabric_moderate_026_new.jpg',
#    'fabric_moderate_027_new.jpg',
#    'fabric_moderate_028_new.jpg',
#    'fabric_moderate_029_new.jpg',
#    'fabric_moderate_030_new.jpg',
#    'fabric_moderate_031_new.jpg',
#    'fabric_moderate_032_new.jpg',
#    'fabric_moderate_033_new.jpg',
#    'fabric_moderate_034_new.jpg',
#    'fabric_moderate_035_new.jpg',
#    'fabric_moderate_036_new.jpg',
#    'fabric_moderate_037_new.jpg',
#    'fabric_moderate_038_new.jpg',
#    'fabric_moderate_039_new.jpg',
#    'fabric_moderate_040_new.jpg',
#    'fabric_moderate_041_new.jpg',
#    'fabric_moderate_042_new.jpg',
#    'fabric_moderate_043_new.jpg',
#    'fabric_moderate_044_new.jpg',
#    'fabric_moderate_045_new.jpg',
#    'fabric_moderate_046_new.jpg',
#    'fabric_moderate_047_new.jpg',
#    'fabric_moderate_048_new.jpg',
#    'fabric_moderate_049_new.jpg',
#    'fabric_moderate_050_new.jpg',
#    'fabric_object_001_new.jpg',
#    'fabric_object_002_new.jpg',
#    'fabric_object_003_new.jpg',
#    'fabric_object_004_new.jpg',
#    'fabric_object_005_new.jpg',
#    'fabric_object_006_new.jpg',
#    'fabric_object_007_new.jpg',
#    'fabric_object_008_new.jpg',
#    'fabric_object_009_new.jpg',
#    'fabric_object_010_new.jpg',
#    'fabric_object_011_new.jpg',
#    'fabric_object_012_new.jpg',
#    'fabric_object_013_new.jpg',
#    'fabric_object_014_new.jpg',
#    'fabric_object_015_new.jpg',
#    'fabric_object_016_new.jpg',
#    'fabric_object_017_new.jpg',
#    'fabric_object_018_new.jpg',
#    'fabric_object_019_new.jpg',
#    'fabric_object_020_new.jpg',
#    'fabric_object_021_new.jpg',
#    'fabric_object_022_new.jpg',
#    'fabric_object_023_new.jpg',
#    'fabric_object_024_new.jpg',
#    'fabric_object_025_new.jpg',
#    'fabric_object_026_new.jpg',
#    'fabric_object_027_new.jpg',
#    'fabric_object_028_new.jpg',
#    'fabric_object_029_new.jpg',
#    'fabric_object_030_new.jpg',
#    'fabric_object_031_new.jpg',
#    'fabric_object_032_new.jpg',
#    'fabric_object_033_new.jpg',
#    'fabric_object_034_new.jpg',
#    'fabric_object_035_new.jpg',
#    'fabric_object_036_new.jpg',
#    'fabric_object_037_new.jpg',
#    'fabric_object_038_new.jpg',
#    'fabric_object_039_new.jpg',
#    'fabric_object_040_new.jpg',
#    'fabric_object_041_new.jpg',
#    'fabric_object_042_new.jpg',
#    'fabric_object_043_new.jpg',
#    'fabric_object_044_new.jpg',
#    'fabric_object_045_new.jpg',
#    'fabric_object_046_new.jpg',
#    'fabric_object_047_new.jpg',
#    'fabric_object_048_new.jpg',
#    'fabric_object_049_new.jpg',
#    'fabric_object_050_new.jpg']},
#  {'label': 'foliage',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\foliage',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\foliage',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\foliage',
#   'images': ['foliage_final_001_new.jpg',
#    'foliage_final_002_new.jpg',
#    'foliage_final_003_new.jpg',
#    'foliage_final_004_new.jpg',
#    'foliage_final_005_new.jpg',
#    'foliage_final_006_new.jpg',
#    'foliage_final_007_new.jpg',
#    'foliage_final_008_new.jpg',
#    'foliage_final_009_new.jpg',
#    'foliage_final_010_new.jpg',
#    'foliage_final_011_new.jpg',
#    'foliage_final_012_new.jpg',
#    'foliage_final_013_new.jpg',
#    'foliage_final_014_new.jpg',
#    'foliage_final_015_new.jpg',
#    'foliage_final_016_new.jpg',
#    'foliage_final_017_new.jpg',
#    'foliage_final_018_new.jpg',
#    'foliage_final_019_new.jpg',
#    'foliage_final_020_new.jpg',
#    'foliage_final_021_new.jpg',
#    'foliage_final_022_new.jpg',
#    'foliage_final_023_new.jpg',
#    'foliage_final_024_new.jpg',
#    'foliage_final_025_new.jpg',
#    'foliage_final_026_new.jpg',
#    'foliage_final_027_new.jpg',
#    'foliage_final_028_new.jpg',
#    'foliage_final_029_new.jpg',
#    'foliage_final_030_new.jpg',
#    'foliage_final_031_new.jpg',
#    'foliage_final_032_new.jpg',
#    'foliage_final_033_new.jpg',
#    'foliage_final_034_new.jpg',
#    'foliage_final_035_new.jpg',
#    'foliage_final_036_new.jpg',
#    'foliage_final_037_new.jpg',
#    'foliage_final_038_new.jpg',
#    'foliage_final_039_new.jpg',
#    'foliage_final_040_new.jpg',
#    'foliage_final_041_new.jpg',
#    'foliage_final_042_new.jpg',
#    'foliage_final_043_new.jpg',
#    'foliage_final_044_new.jpg',
#    'foliage_final_045_new.jpg',
#    'foliage_final_046_new.jpg',
#    'foliage_final_047_new.jpg',
#    'foliage_final_048_new.jpg',
#    'foliage_final_049_new.jpg',
#    'foliage_final_050_new.jpg',
#    'foliage_final_051_new.jpg',
#    'foliage_final_052_new.jpg',
#    'foliage_final_053_new.jpg',
#    'foliage_final_054_new.jpg',
#    'foliage_final_055_new.jpg',
#    'foliage_final_056_new.jpg',
#    'foliage_final_057_new.jpg',
#    'foliage_final_058_new.jpg',
#    'foliage_final_059_new.jpg',
#    'foliage_final_060_new.jpg',
#    'foliage_final_061_new.jpg',
#    'foliage_final_062_new.jpg',
#    'foliage_final_063_new.jpg',
#    'foliage_final_064_new.jpg',
#    'foliage_final_065_new.jpg',
#    'foliage_final_066_new.jpg',
#    'foliage_final_067_new.jpg',
#    'foliage_final_068_new.jpg',
#    'foliage_final_069_new.jpg',
#    'foliage_final_070_new.jpg',
#    'foliage_final_071_new.jpg',
#    'foliage_final_072_new.jpg',
#    'foliage_final_073_new.jpg',
#    'foliage_final_074_new.jpg',
#    'foliage_final_075_new.jpg',
#    'foliage_final_076_new.jpg',
#    'foliage_final_077_new.jpg',
#    'foliage_final_078_new.jpg',
#    'foliage_final_079_new.jpg',
#    'foliage_final_080_new.jpg',
#    'foliage_final_081_new.jpg',
#    'foliage_final_082_new.jpg',
#    'foliage_final_083_new.jpg',
#    'foliage_final_084_new.jpg',
#    'foliage_final_085_new.jpg',
#    'foliage_final_086_new.jpg',
#    'foliage_final_087_new.jpg',
#    'foliage_final_088_new.jpg',
#    'foliage_final_089_new.jpg',
#    'foliage_final_090_new.jpg',
#    'foliage_final_091_new.jpg',
#    'foliage_final_092_new.jpg',
#    'foliage_final_093_new.jpg',
#    'foliage_final_094_new.jpg',
#    'foliage_final_095_new.jpg',
#    'foliage_final_096_new.jpg',
#    'foliage_final_097_new.jpg',
#    'foliage_final_098_new.jpg',
#    'foliage_final_099_new.jpg',
#    'foliage_final_100_new.jpg']},
#  {'label': 'glass',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\glass',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\glass',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\glass',
#   'images': ['glass_moderate_001_new.jpg',
#    'glass_moderate_002_new.jpg',
#    'glass_moderate_003_new.jpg',
#    'glass_moderate_004_new.jpg',
#    'glass_moderate_005_new.jpg',
#    'glass_moderate_006_new.jpg',
#    'glass_moderate_007_new.jpg',
#    'glass_moderate_008_new.jpg',
#    'glass_moderate_009_new.jpg',
#    'glass_moderate_010_new.jpg',
#    'glass_moderate_011_new.jpg',
#    'glass_moderate_012_new.jpg',
#    'glass_moderate_013_new.jpg',
#    'glass_moderate_014_new.jpg',
#    'glass_moderate_015_new.jpg',
#    'glass_moderate_016_new.jpg',
#    'glass_moderate_017_new.jpg',
#    'glass_moderate_018_new.jpg',
#    'glass_moderate_019_new.jpg',
#    'glass_moderate_020_new.jpg',
#    'glass_moderate_021_new.jpg',
#    'glass_moderate_022_new.jpg',
#    'glass_moderate_023_new.jpg',
#    'glass_moderate_024_new.jpg',
#    'glass_moderate_025_new.jpg',
#    'glass_moderate_026_new.jpg',
#    'glass_moderate_027_new.jpg',
#    'glass_moderate_028_new.jpg',
#    'glass_moderate_029_new.jpg',
#    'glass_moderate_030_new.jpg',
#    'glass_moderate_031_new.jpg',
#    'glass_moderate_032_new.jpg',
#    'glass_moderate_033_new.jpg',
#    'glass_moderate_034_new.jpg',
#    'glass_moderate_035_new.jpg',
#    'glass_moderate_036_new.jpg',
#    'glass_moderate_037_new.jpg',
#    'glass_moderate_038_new.jpg',
#    'glass_moderate_039_new.jpg',
#    'glass_moderate_040_new.jpg',
#    'glass_moderate_041_new.jpg',
#    'glass_moderate_042_new.jpg',
#    'glass_moderate_043_new.jpg',
#    'glass_moderate_044_new.jpg',
#    'glass_moderate_045_new.jpg',
#    'glass_moderate_046_new.jpg',
#    'glass_moderate_047_new.jpg',
#    'glass_moderate_048_new.jpg',
#    'glass_moderate_049_new.jpg',
#    'glass_moderate_050_new.jpg',
#    'glass_object_001_new.jpg',
#    'glass_object_002_new.jpg',
#    'glass_object_003_new.jpg',
#    'glass_object_004_new.jpg',
#    'glass_object_005_new.jpg',
#    'glass_object_006_new.jpg',
#    'glass_object_007_new.jpg',
#    'glass_object_008_new.jpg',
#    'glass_object_009_new.jpg',
#    'glass_object_010_new.jpg',
#    'glass_object_011_new.jpg',
#    'glass_object_012_new.jpg',
#    'glass_object_013_new.jpg',
#    'glass_object_014_new.jpg',
#    'glass_object_015_new.jpg',
#    'glass_object_016_new.jpg',
#    'glass_object_017_new.jpg',
#    'glass_object_018_new.jpg',
#    'glass_object_019_new.jpg',
#    'glass_object_020_new.jpg',
#    'glass_object_021_new.jpg',
#    'glass_object_022_new.jpg',
#    'glass_object_023_new.jpg',
#    'glass_object_024_new.jpg',
#    'glass_object_025_new.jpg',
#    'glass_object_026_new.jpg',
#    'glass_object_027_new.jpg',
#    'glass_object_028_new.jpg',
#    'glass_object_029_new.jpg',
#    'glass_object_030_new.jpg',
#    'glass_object_031_new.jpg',
#    'glass_object_032_new.jpg',
#    'glass_object_033_new.jpg',
#    'glass_object_034_new.jpg',
#    'glass_object_035_new.jpg',
#    'glass_object_036_new.jpg',
#    'glass_object_037_new.jpg',
#    'glass_object_038_new.jpg',
#    'glass_object_039_new.jpg',
#    'glass_object_040_new.jpg',
#    'glass_object_041_new.jpg',
#    'glass_object_042_new.jpg',
#    'glass_object_043_new.jpg',
#    'glass_object_044_new.jpg',
#    'glass_object_045_new.jpg',
#    'glass_object_046_new.jpg',
#    'glass_object_047_new.jpg',
#    'glass_object_048_new.jpg',
#    'glass_object_049_new.jpg',
#    'glass_object_050_new.jpg']},
#  {'label': 'leather',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\leather',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\leather',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\leather',
#   'images': ['leather_moderate_001_new.jpg',
#    'leather_moderate_002_new.jpg',
#    'leather_moderate_003_new.jpg',
#    'leather_moderate_004_new.jpg',
#    'leather_moderate_005_new.jpg',
#    'leather_moderate_006_new.jpg',
#    'leather_moderate_007_new.jpg',
#    'leather_moderate_008_new.jpg',
#    'leather_moderate_009_new.jpg',
#    'leather_moderate_010_new.jpg',
#    'leather_moderate_011_new.jpg',
#    'leather_moderate_012_new.jpg',
#    'leather_moderate_013_new.jpg',
#    'leather_moderate_014_new.jpg',
#    'leather_moderate_015_new.jpg',
#    'leather_moderate_016_new.jpg',
#    'leather_moderate_017_new.jpg',
#    'leather_moderate_018_new.jpg',
#    'leather_moderate_019_new.jpg',
#    'leather_moderate_020_new.jpg',
#    'leather_moderate_021_new.jpg',
#    'leather_moderate_022_new.jpg',
#    'leather_moderate_023_new.jpg',
#    'leather_moderate_024_new.jpg',
#    'leather_moderate_025_new.jpg',
#    'leather_moderate_026_new.jpg',
#    'leather_moderate_027_new.jpg',
#    'leather_moderate_028_new.jpg',
#    'leather_moderate_029_new.jpg',
#    'leather_moderate_030_new.jpg',
#    'leather_moderate_031_new.jpg',
#    'leather_moderate_032_new.jpg',
#    'leather_moderate_033_new.jpg',
#    'leather_moderate_034_new.jpg',
#    'leather_moderate_035_new.jpg',
#    'leather_moderate_036_new.jpg',
#    'leather_moderate_037_new.jpg',
#    'leather_moderate_038_new.jpg',
#    'leather_moderate_039_new.jpg',
#    'leather_moderate_040_new.jpg',
#    'leather_moderate_041_new.jpg',
#    'leather_moderate_042_new.jpg',
#    'leather_moderate_043_new.jpg',
#    'leather_moderate_044_new.jpg',
#    'leather_moderate_045_new.jpg',
#    'leather_moderate_046_new.jpg',
#    'leather_moderate_047_new.jpg',
#    'leather_moderate_048_new.jpg',
#    'leather_moderate_049_new.jpg',
#    'leather_moderate_050_new.jpg',
#    'leather_object_001_new.jpg',
#    'leather_object_002_new.jpg',
#    'leather_object_003_new.jpg',
#    'leather_object_004_new.jpg',
#    'leather_object_005_new.jpg',
#    'leather_object_006_new.jpg',
#    'leather_object_007_new.jpg',
#    'leather_object_008_new.jpg',
#    'leather_object_009_new.jpg',
#    'leather_object_010_new.jpg',
#    'leather_object_011_new.jpg',
#    'leather_object_012_new.jpg',
#    'leather_object_013_new.jpg',
#    'leather_object_014_new.jpg',
#    'leather_object_015_new.jpg',
#    'leather_object_016_new.jpg',
#    'leather_object_017_new.jpg',
#    'leather_object_018_new.jpg',
#    'leather_object_019_new.jpg',
#    'leather_object_020_new.jpg',
#    'leather_object_021_new.jpg',
#    'leather_object_022_new.jpg',
#    'leather_object_023_new.jpg',
#    'leather_object_024_new.jpg',
#    'leather_object_025_new.jpg',
#    'leather_object_026_new.jpg',
#    'leather_object_027_new.jpg',
#    'leather_object_028_new.jpg',
#    'leather_object_029_new.jpg',
#    'leather_object_030_new.jpg',
#    'leather_object_031_new.jpg',
#    'leather_object_032_new.jpg',
#    'leather_object_033_new.jpg',
#    'leather_object_034_new.jpg',
#    'leather_object_035_new.jpg',
#    'leather_object_036_new.jpg',
#    'leather_object_037_new.jpg',
#    'leather_object_038_new.jpg',
#    'leather_object_039_new.jpg',
#    'leather_object_040_new.jpg',
#    'leather_object_041_new.jpg',
#    'leather_object_042_new.jpg',
#    'leather_object_043_new.jpg',
#    'leather_object_044_new.jpg',
#    'leather_object_045_new.jpg',
#    'leather_object_046_new.jpg',
#    'leather_object_047_new.jpg',
#    'leather_object_048_new.jpg',
#    'leather_object_049_new.jpg',
#    'leather_object_050_new.jpg']},
#  {'label': 'metal',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\metal',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\metal',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\metal',
#   'images': ['metal_moderate_001_new.jpg',
#    'metal_moderate_002_new.jpg',
#    'metal_moderate_003_new.jpg',
#    'metal_moderate_004_new.jpg',
#    'metal_moderate_005_new.jpg',
#    'metal_moderate_006_new.jpg',
#    'metal_moderate_007_new.jpg',
#    'metal_moderate_008_new.jpg',
#    'metal_moderate_009_new.jpg',
#    'metal_moderate_010_new.jpg',
#    'metal_moderate_011_new.jpg',
#    'metal_moderate_012_new.jpg',
#    'metal_moderate_013_new.jpg',
#    'metal_moderate_014_new.jpg',
#    'metal_moderate_015_new.jpg',
#    'metal_moderate_016_new.jpg',
#    'metal_moderate_017_new.jpg',
#    'metal_moderate_018_new.jpg',
#    'metal_moderate_019_new.jpg',
#    'metal_moderate_020_new.jpg',
#    'metal_moderate_021_new.jpg',
#    'metal_moderate_022_new.jpg',
#    'metal_moderate_023_new.jpg',
#    'metal_moderate_024_new.jpg',
#    'metal_moderate_025_new.jpg',
#    'metal_moderate_026_new.jpg',
#    'metal_moderate_027_new.jpg',
#    'metal_moderate_028_new.jpg',
#    'metal_moderate_029_new.jpg',
#    'metal_moderate_030_new.jpg',
#    'metal_moderate_031_new.jpg',
#    'metal_moderate_032_new.jpg',
#    'metal_moderate_033_new.jpg',
#    'metal_moderate_034_new.jpg',
#    'metal_moderate_035_new.jpg',
#    'metal_moderate_036_new.jpg',
#    'metal_moderate_037_new.jpg',
#    'metal_moderate_038_new.jpg',
#    'metal_moderate_039_new.jpg',
#    'metal_moderate_040_new.jpg',
#    'metal_moderate_041_new.jpg',
#    'metal_moderate_042_new.jpg',
#    'metal_moderate_043_new.jpg',
#    'metal_moderate_044_new.jpg',
#    'metal_moderate_045_new.jpg',
#    'metal_moderate_046_new.jpg',
#    'metal_moderate_047_new.jpg',
#    'metal_moderate_048_new.jpg',
#    'metal_moderate_049_new.jpg',
#    'metal_moderate_050_new.jpg',
#    'metal_object_001_new.jpg',
#    'metal_object_002_new.jpg',
#    'metal_object_003_new.jpg',
#    'metal_object_004_new.jpg',
#    'metal_object_005_new.jpg',
#    'metal_object_006_new.jpg',
#    'metal_object_007_new.jpg',
#    'metal_object_008_new.jpg',
#    'metal_object_009_new.jpg',
#    'metal_object_010_new.jpg',
#    'metal_object_011_new.jpg',
#    'metal_object_012_new.jpg',
#    'metal_object_013_new.jpg',
#    'metal_object_014_new.jpg',
#    'metal_object_015_new.jpg',
#    'metal_object_016_new.jpg',
#    'metal_object_017_new.jpg',
#    'metal_object_018_new.jpg',
#    'metal_object_019_new.jpg',
#    'metal_object_020_new.jpg',
#    'metal_object_021_new.jpg',
#    'metal_object_022_new.jpg',
#    'metal_object_023_new.jpg',
#    'metal_object_024_new.jpg',
#    'metal_object_025_new.jpg',
#    'metal_object_026_new.jpg',
#    'metal_object_027_new.jpg',
#    'metal_object_028_new.jpg',
#    'metal_object_029_new.jpg',
#    'metal_object_030_new.jpg',
#    'metal_object_031_new.jpg',
#    'metal_object_032_new.jpg',
#    'metal_object_033_new.jpg',
#    'metal_object_034_new.jpg',
#    'metal_object_035_new.jpg',
#    'metal_object_036_new.jpg',
#    'metal_object_037_new.jpg',
#    'metal_object_038_new.jpg',
#    'metal_object_039_new.jpg',
#    'metal_object_040_new.jpg',
#    'metal_object_041_new.jpg',
#    'metal_object_042_new.jpg',
#    'metal_object_043_new.jpg',
#    'metal_object_044_new.jpg',
#    'metal_object_045_new.jpg',
#    'metal_object_046_new.jpg',
#    'metal_object_047_new.jpg',
#    'metal_object_048_new.jpg',
#    'metal_object_049_new.jpg',
#    'metal_object_050_new.jpg']},
#  {'label': 'paper',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\paper',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\paper',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\paper',
#   'images': ['paper_moderate_001_new.jpg',
#    'paper_moderate_002_new.jpg',
#    'paper_moderate_003_new.jpg',
#    'paper_moderate_004_new.jpg',
#    'paper_moderate_005_new.jpg',
#    'paper_moderate_006_new.jpg',
#    'paper_moderate_007_new.jpg',
#    'paper_moderate_008_new.jpg',
#    'paper_moderate_009_new.jpg',
#    'paper_moderate_010_new.jpg',
#    'paper_moderate_011_new.jpg',
#    'paper_moderate_012_new.jpg',
#    'paper_moderate_013_new.jpg',
#    'paper_moderate_014_new.jpg',
#    'paper_moderate_015_new.jpg',
#    'paper_moderate_016_new.jpg',
#    'paper_moderate_017_new.jpg',
#    'paper_moderate_018_new.jpg',
#    'paper_moderate_019_new.jpg',
#    'paper_moderate_020_new.jpg',
#    'paper_moderate_021_new.jpg',
#    'paper_moderate_022_new.jpg',
#    'paper_moderate_023_new.jpg',
#    'paper_moderate_024_new.jpg',
#    'paper_moderate_025_new.jpg',
#    'paper_moderate_026_new.jpg',
#    'paper_moderate_027_new.jpg',
#    'paper_moderate_028_new.jpg',
#    'paper_moderate_029_new.jpg',
#    'paper_moderate_030_new.jpg',
#    'paper_moderate_031_new.jpg',
#    'paper_moderate_032_new.jpg',
#    'paper_moderate_033_new.jpg',
#    'paper_moderate_034_new.jpg',
#    'paper_moderate_035_new.jpg',
#    'paper_moderate_036_new.jpg',
#    'paper_moderate_037_new.jpg',
#    'paper_moderate_038_new.jpg',
#    'paper_moderate_039_new.jpg',
#    'paper_moderate_040_new.jpg',
#    'paper_moderate_041_new.jpg',
#    'paper_moderate_042_new.jpg',
#    'paper_moderate_043_new.jpg',
#    'paper_moderate_044_new.jpg',
#    'paper_moderate_045_new.jpg',
#    'paper_moderate_046_new.jpg',
#    'paper_moderate_047_new.jpg',
#    'paper_moderate_048_new.jpg',
#    'paper_moderate_049_new.jpg',
#    'paper_moderate_050_new.jpg',
#    'paper_object_001_new.jpg',
#    'paper_object_002_new.jpg',
#    'paper_object_003_new.jpg',
#    'paper_object_004_new.jpg',
#    'paper_object_005_new.jpg',
#    'paper_object_006_new.jpg',
#    'paper_object_007_new.jpg',
#    'paper_object_008_new.jpg',
#    'paper_object_009_new.jpg',
#    'paper_object_010_new.jpg',
#    'paper_object_011_new.jpg',
#    'paper_object_012_new.jpg',
#    'paper_object_013_new.jpg',
#    'paper_object_014_new.jpg',
#    'paper_object_015_new.jpg',
#    'paper_object_016_new.jpg',
#    'paper_object_017_new.jpg',
#    'paper_object_018_new.jpg',
#    'paper_object_019_new.jpg',
#    'paper_object_020_new.jpg',
#    'paper_object_021_new.jpg',
#    'paper_object_022_new.jpg',
#    'paper_object_023_new.jpg',
#    'paper_object_024_new.jpg',
#    'paper_object_025_new.jpg',
#    'paper_object_026_new.jpg',
#    'paper_object_027_new.jpg',
#    'paper_object_028_new.jpg',
#    'paper_object_029_new.jpg',
#    'paper_object_030_new.jpg',
#    'paper_object_031_new.jpg',
#    'paper_object_032_new.jpg',
#    'paper_object_033_new.jpg',
#    'paper_object_034_new.jpg',
#    'paper_object_035_new.jpg',
#    'paper_object_036_new.jpg',
#    'paper_object_037_new.jpg',
#    'paper_object_038_new.jpg',
#    'paper_object_039_new.jpg',
#    'paper_object_040_new.jpg',
#    'paper_object_041_new.jpg',
#    'paper_object_042_new.jpg',
#    'paper_object_043_new.jpg',
#    'paper_object_044_new.jpg',
#    'paper_object_045_new.jpg',
#    'paper_object_046_new.jpg',
#    'paper_object_047_new.jpg',
#    'paper_object_048_new.jpg',
#    'paper_object_049_new.jpg',
#    'paper_object_050_new.jpg']},
#  {'label': 'plastic',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\plastic',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\plastic',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\plastic',
#   'images': ['plastic_moderate_001_new.jpg',
#    'plastic_moderate_002_new.jpg',
#    'plastic_moderate_003_new.jpg',
#    'plastic_moderate_004_new.jpg',
#    'plastic_moderate_005_new.jpg',
#    'plastic_moderate_006_new.jpg',
#    'plastic_moderate_007_new.jpg',
#    'plastic_moderate_008_new.jpg',
#    'plastic_moderate_009_new.jpg',
#    'plastic_moderate_010_new.jpg',
#    'plastic_moderate_011_new.jpg',
#    'plastic_moderate_012_new.jpg',
#    'plastic_moderate_013_new.jpg',
#    'plastic_moderate_014_new.jpg',
#    'plastic_moderate_015_new.jpg',
#    'plastic_moderate_016_new.jpg',
#    'plastic_moderate_017_new.jpg',
#    'plastic_moderate_018_new.jpg',
#    'plastic_moderate_019_new.jpg',
#    'plastic_moderate_020_new.jpg',
#    'plastic_moderate_021_new.jpg',
#    'plastic_moderate_022_new.jpg',
#    'plastic_moderate_023_new.jpg',
#    'plastic_moderate_024_new.jpg',
#    'plastic_moderate_025_new.jpg',
#    'plastic_moderate_026_new.jpg',
#    'plastic_moderate_027_new.jpg',
#    'plastic_moderate_028_new.jpg',
#    'plastic_moderate_029_new.jpg',
#    'plastic_moderate_030_new.jpg',
#    'plastic_moderate_031_new.jpg',
#    'plastic_moderate_032_new.jpg',
#    'plastic_moderate_033_new.jpg',
#    'plastic_moderate_034_new.jpg',
#    'plastic_moderate_035_new.jpg',
#    'plastic_moderate_036_new.jpg',
#    'plastic_moderate_037_new.jpg',
#    'plastic_moderate_038_new.jpg',
#    'plastic_moderate_039_new.jpg',
#    'plastic_moderate_040_new.jpg',
#    'plastic_moderate_041_new.jpg',
#    'plastic_moderate_042_new.jpg',
#    'plastic_moderate_043_new.jpg',
#    'plastic_moderate_044_new.jpg',
#    'plastic_moderate_045_new.jpg',
#    'plastic_moderate_046_new.jpg',
#    'plastic_moderate_047_new.jpg',
#    'plastic_moderate_048_new.jpg',
#    'plastic_moderate_049_new.jpg',
#    'plastic_moderate_050_new.jpg',
#    'plastic_object_001_new.jpg',
#    'plastic_object_002_new.jpg',
#    'plastic_object_003_new.jpg',
#    'plastic_object_004_new.jpg',
#    'plastic_object_005_new.jpg',
#    'plastic_object_006_new.jpg',
#    'plastic_object_007_new.jpg',
#    'plastic_object_008_new.jpg',
#    'plastic_object_009_new.jpg',
#    'plastic_object_010_new.jpg',
#    'plastic_object_011_new.jpg',
#    'plastic_object_012_new.jpg',
#    'plastic_object_013_new.jpg',
#    'plastic_object_014_new.jpg',
#    'plastic_object_015_new.jpg',
#    'plastic_object_016_new.jpg',
#    'plastic_object_017_new.jpg',
#    'plastic_object_018_new.jpg',
#    'plastic_object_019_new.jpg',
#    'plastic_object_020_new.jpg',
#    'plastic_object_021_new.jpg',
#    'plastic_object_022_new.jpg',
#    'plastic_object_023_new.jpg',
#    'plastic_object_024_new.jpg',
#    'plastic_object_025_new.jpg',
#    'plastic_object_026_new.jpg',
#    'plastic_object_027_new.jpg',
#    'plastic_object_028_new.jpg',
#    'plastic_object_029_new.jpg',
#    'plastic_object_030_new.jpg',
#    'plastic_object_031_new.jpg',
#    'plastic_object_032_new.jpg',
#    'plastic_object_033_new.jpg',
#    'plastic_object_034_new.jpg',
#    'plastic_object_035_new.jpg',
#    'plastic_object_036_new.jpg',
#    'plastic_object_037_new.jpg',
#    'plastic_object_038_new.jpg',
#    'plastic_object_039_new.jpg',
#    'plastic_object_040_new.jpg',
#    'plastic_object_041_new.jpg',
#    'plastic_object_042_new.jpg',
#    'plastic_object_043_new.jpg',
#    'plastic_object_044_new.jpg',
#    'plastic_object_045_new.jpg',
#    'plastic_object_046_new.jpg',
#    'plastic_object_047_new.jpg',
#    'plastic_object_048_new.jpg',
#    'plastic_object_049_new.jpg',
#    'plastic_object_050_new.jpg']},
#  {'label': 'stone',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\stone',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\stone',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\stone',
#   'images': ['stone_moderate_001_new.jpg',
#    'stone_moderate_002_new.jpg',
#    'stone_moderate_003_new.jpg',
#    'stone_moderate_004_new.jpg',
#    'stone_moderate_005_new.jpg',
#    'stone_moderate_006_new.jpg',
#    'stone_moderate_007_new.jpg',
#    'stone_moderate_008_new.jpg',
#    'stone_moderate_009_new.jpg',
#    'stone_moderate_010_new.jpg',
#    'stone_moderate_011_new.jpg',
#    'stone_moderate_012_new.jpg',
#    'stone_moderate_013_new.jpg',
#    'stone_moderate_014_new.jpg',
#    'stone_moderate_015_new.jpg',
#    'stone_moderate_016_new.jpg',
#    'stone_moderate_017_new.jpg',
#    'stone_moderate_018_new.jpg',
#    'stone_moderate_019_new.jpg',
#    'stone_moderate_020_new.jpg',
#    'stone_moderate_021_new.jpg',
#    'stone_moderate_022_new.jpg',
#    'stone_moderate_023_new.jpg',
#    'stone_moderate_024_new.jpg',
#    'stone_moderate_025_new.jpg',
#    'stone_moderate_026_new.jpg',
#    'stone_moderate_027_new.jpg',
#    'stone_moderate_028_new.jpg',
#    'stone_moderate_029_new.jpg',
#    'stone_moderate_030_new.jpg',
#    'stone_moderate_031_new.jpg',
#    'stone_moderate_032_new.jpg',
#    'stone_moderate_033_new.jpg',
#    'stone_moderate_034_new.jpg',
#    'stone_moderate_035_new.jpg',
#    'stone_moderate_036_new.jpg',
#    'stone_moderate_037_new.jpg',
#    'stone_moderate_038_new.jpg',
#    'stone_moderate_039_new.jpg',
#    'stone_moderate_040_new.jpg',
#    'stone_moderate_041_new.jpg',
#    'stone_moderate_042_new.jpg',
#    'stone_moderate_043_new.jpg',
#    'stone_moderate_044_new.jpg',
#    'stone_moderate_045_new.jpg',
#    'stone_moderate_046_new.jpg',
#    'stone_moderate_047_new.jpg',
#    'stone_moderate_048_new.jpg',
#    'stone_moderate_049_new.jpg',
#    'stone_moderate_050_new.jpg',
#    'stone_object_001_new.jpg',
#    'stone_object_002_new.jpg',
#    'stone_object_003_new.jpg',
#    'stone_object_004_new.jpg',
#    'stone_object_005_new.jpg',
#    'stone_object_006_new.jpg',
#    'stone_object_007_new.jpg',
#    'stone_object_008_new.jpg',
#    'stone_object_009_new.jpg',
#    'stone_object_010_new.jpg',
#    'stone_object_011_new.jpg',
#    'stone_object_012_new.jpg',
#    'stone_object_013_new.jpg',
#    'stone_object_014_new.jpg',
#    'stone_object_015_new.jpg',
#    'stone_object_016_new.jpg',
#    'stone_object_017_new.jpg',
#    'stone_object_018_new.jpg',
#    'stone_object_019_new.jpg',
#    'stone_object_020_new.jpg',
#    'stone_object_021_new.jpg',
#    'stone_object_022_new.jpg',
#    'stone_object_023_new.jpg',
#    'stone_object_024_new.jpg',
#    'stone_object_025_new.jpg',
#    'stone_object_026_new.jpg',
#    'stone_object_027_new.jpg',
#    'stone_object_028_new.jpg',
#    'stone_object_029_new.jpg',
#    'stone_object_030_new.jpg',
#    'stone_object_031_new.jpg',
#    'stone_object_032_new.jpg',
#    'stone_object_033_new.jpg',
#    'stone_object_034_new.jpg',
#    'stone_object_035_new.jpg',
#    'stone_object_036_new.jpg',
#    'stone_object_037_new.jpg',
#    'stone_object_038_new.jpg',
#    'stone_object_039_new.jpg',
#    'stone_object_040_new.jpg',
#    'stone_object_041_new.jpg',
#    'stone_object_042_new.jpg',
#    'stone_object_043_new.jpg',
#    'stone_object_044_new.jpg',
#    'stone_object_045_new.jpg',
#    'stone_object_046_new.jpg',
#    'stone_object_047_new.jpg',
#    'stone_object_048_new.jpg',
#    'stone_object_049_new.jpg',
#    'stone_object_050_new.jpg']},
#  {'label': 'water',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\water',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\water',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\water',
#   'images': ['water_moderate_001_new.jpg',
#    'water_moderate_002_new.jpg',
#    'water_moderate_003_new.jpg',
#    'water_moderate_004_new.jpg',
#    'water_moderate_005_new.jpg',
#    'water_moderate_006_new.jpg',
#    'water_moderate_007_new.jpg',
#    'water_moderate_008_new.jpg',
#    'water_moderate_009_new.jpg',
#    'water_moderate_010_new.jpg',
#    'water_moderate_011_new.jpg',
#    'water_moderate_012_new.jpg',
#    'water_moderate_013_new.jpg',
#    'water_moderate_014_new.jpg',
#    'water_moderate_015_new.jpg',
#    'water_moderate_016_new.jpg',
#    'water_moderate_017_new.jpg',
#    'water_moderate_018_new.jpg',
#    'water_moderate_019_new.jpg',
#    'water_moderate_020_new.jpg',
#    'water_moderate_021_new.jpg',
#    'water_moderate_022_new.jpg',
#    'water_moderate_023_new.jpg',
#    'water_moderate_024_new.jpg',
#    'water_moderate_025_new.jpg',
#    'water_moderate_026_new.jpg',
#    'water_moderate_027_new.jpg',
#    'water_moderate_028_new.jpg',
#    'water_moderate_029_new.jpg',
#    'water_moderate_030_new.jpg',
#    'water_moderate_031_new.jpg',
#    'water_moderate_032_new.jpg',
#    'water_moderate_033_new.jpg',
#    'water_moderate_034_new.jpg',
#    'water_moderate_035_new.jpg',
#    'water_moderate_036_new.jpg',
#    'water_moderate_037_new.jpg',
#    'water_moderate_038_new.jpg',
#    'water_moderate_039_new.jpg',
#    'water_moderate_040_new.jpg',
#    'water_moderate_041_new.jpg',
#    'water_moderate_042_new.jpg',
#    'water_moderate_043_new.jpg',
#    'water_moderate_044_new.jpg',
#    'water_moderate_045_new.jpg',
#    'water_moderate_046_new.jpg',
#    'water_moderate_047_new.jpg',
#    'water_moderate_048_new.jpg',
#    'water_moderate_049_new.jpg',
#    'water_moderate_050_new.jpg',
#    'water_object_001_new.jpg',
#    'water_object_002_new.jpg',
#    'water_object_003_new.jpg',
#    'water_object_004_new.jpg',
#    'water_object_005_new.jpg',
#    'water_object_006_new.jpg',
#    'water_object_007_new.jpg',
#    'water_object_008_new.jpg',
#    'water_object_009_new.jpg',
#    'water_object_010_new.jpg',
#    'water_object_011_new.jpg',
#    'water_object_012_new.jpg',
#    'water_object_013_new.jpg',
#    'water_object_014_new.jpg',
#    'water_object_015_new.jpg',
#    'water_object_016_new.jpg',
#    'water_object_017_new.jpg',
#    'water_object_018_new.jpg',
#    'water_object_019_new.jpg',
#    'water_object_020_new.jpg',
#    'water_object_021_new.jpg',
#    'water_object_022_new.jpg',
#    'water_object_023_new.jpg',
#    'water_object_024_new.jpg',
#    'water_object_025_new.jpg',
#    'water_object_026_new.jpg',
#    'water_object_027_new.jpg',
#    'water_object_028_new.jpg',
#    'water_object_029_new.jpg',
#    'water_object_030_new.jpg',
#    'water_object_031_new.jpg',
#    'water_object_032_new.jpg',
#    'water_object_033_new.jpg',
#    'water_object_034_new.jpg',
#    'water_object_035_new.jpg',
#    'water_object_036_new.jpg',
#    'water_object_037_new.jpg',
#    'water_object_038_new.jpg',
#    'water_object_039_new.jpg',
#    'water_object_040_new.jpg',
#    'water_object_041_new.jpg',
#    'water_object_042_new.jpg',
#    'water_object_043_new.jpg',
#    'water_object_044_new.jpg',
#    'water_object_045_new.jpg',
#    'water_object_046_new.jpg',
#    'water_object_047_new.jpg',
#    'water_object_048_new.jpg',
#    'water_object_049_new.jpg',
#    'water_object_050_new.jpg']},
#  {'label': 'wood',
#   'path': 'D:\\Kaio_Poc_Telhas\\FMD\\image\\wood',
#   'train': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\train\\wood',
#   'val': 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format\\val\\wood',
#   'images': ['wood_moderate_001_new.jpg',
#    'wood_moderate_002_new.jpg',
#    'wood_moderate_003_new.jpg',
#    'wood_moderate_004_new.jpg',
#    'wood_moderate_005_new.jpg',
#    'wood_moderate_006_new.jpg',
#    'wood_moderate_007_new.jpg',
#    'wood_moderate_008_new.jpg',
#    'wood_moderate_009_new.jpg',
#    'wood_moderate_010_new.jpg',
#    'wood_moderate_011_new.jpg',
#    'wood_moderate_012_new.jpg',
#    'wood_moderate_013_new.jpg',
#    'wood_moderate_014_new.jpg',
#    'wood_moderate_015_new.jpg',
#    'wood_moderate_016_new.jpg',
#    'wood_moderate_017_new.jpg',
#    'wood_moderate_018_new.jpg',
#    'wood_moderate_019_new.jpg',
#    'wood_moderate_020_new.jpg',
#    'wood_moderate_021_new.jpg',
#    'wood_moderate_022_new.jpg',
#    'wood_moderate_023_new.jpg',
#    'wood_moderate_024_new.jpg',
#    'wood_moderate_025_new.jpg',
#    'wood_moderate_026_new.jpg',
#    'wood_moderate_027_new.jpg',
#    'wood_moderate_028_new.jpg',
#    'wood_moderate_029_new.jpg',
#    'wood_moderate_030_new.jpg',
#    'wood_moderate_031_new.jpg',
#    'wood_moderate_032_new.jpg',
#    'wood_moderate_033_new.jpg',
#    'wood_moderate_034_new.jpg',
#    'wood_moderate_035_new.jpg',
#    'wood_moderate_036_new.jpg',
#    'wood_moderate_037_new.jpg',
#    'wood_moderate_038_new.jpg',
#    'wood_moderate_039_new.jpg',
#    'wood_moderate_040_new.jpg',
#    'wood_moderate_041_new.jpg',
#    'wood_moderate_042_new.jpg',
#    'wood_moderate_043_new.jpg',
#    'wood_moderate_044_new.jpg',
#    'wood_moderate_045_new.jpg',
#    'wood_moderate_046_new.jpg',
#    'wood_moderate_047_new.jpg',
#    'wood_moderate_048_new.jpg',
#    'wood_moderate_049_new.jpg',
#    'wood_moderate_050_new.jpg',
#    'wood_object_001_new.jpg',
#    'wood_object_002_new.jpg',
#    'wood_object_003_new.jpg',
#    'wood_object_004_new.jpg',
#    'wood_object_005_new.jpg',
#    'wood_object_006_new.jpg',
#    'wood_object_007_new.jpg',
#    'wood_object_008_new.jpg',
#    'wood_object_009_new.jpg',
#    'wood_object_010_new.jpg',
#    'wood_object_011_new.jpg',
#    'wood_object_012_new.jpg',
#    'wood_object_013_new.jpg',
#    'wood_object_014_new.jpg',
#    'wood_object_015_new.jpg',
#    'wood_object_016_new.jpg',
#    'wood_object_017_new.jpg',
#    'wood_object_018_new.jpg',
#    'wood_object_019_new.jpg',
#    'wood_object_020_new.jpg',
#    'wood_object_021_new.jpg',
#    'wood_object_022_new.jpg',
#    'wood_object_023_new.jpg',
#    'wood_object_024_new.jpg',
#    'wood_object_025_new.jpg',
#    'wood_object_026_new.jpg',
#    'wood_object_027_new.jpg',
#    'wood_object_028_new.jpg',
#    'wood_object_029_new.jpg',
#    'wood_object_030_new.jpg',
#    'wood_object_031_new.jpg',
#    'wood_object_032_new.jpg',
#    'wood_object_033_new.jpg',
#    'wood_object_034_new.jpg',
#    'wood_object_035_new.jpg',
#    'wood_object_036_new.jpg',
#    'wood_object_037_new.jpg',
#    'wood_object_038_new.jpg',
#    'wood_object_039_new.jpg',
#    'wood_object_040_new.jpg',
#    'wood_object_041_new.jpg',
#    'wood_object_042_new.jpg',
#    'wood_object_043_new.jpg',
#    'wood_object_044_new.jpg',
#    'wood_object_045_new.jpg',
#    'wood_object_046_new.jpg',
#    'wood_object_047_new.jpg',
#    'wood_object_048_new.jpg',
#    'wood_object_049_new.jpg',
#    'wood_object_050_new.jpg']}]

# %%
# Criando pastas no formato do tutorial

train_val_folder = os.path.join(FMD_path, "train_val_format")
for folder in ["train", "val"]:
    folder_fullpath = os.path.join(train_val_folder, folder)
    
    if not os.path.exists(folder_fullpath):
        os.makedirs(folder_fullpath)
        
    for data in images_metadata:
        label_folder_path = os.path.join(folder_fullpath, data["label"])
        
        if not os.path.exists(label_folder_path):
            os.makedirs(label_folder_path)
            
        #data[folder] = label_folder_path

# %%
# Adicionando imagens em cada pasta
# SE EXECUTAR MAIS DE UMA VEZ, VAI ADICIONAR NOVAMENTE AS IMAGENS!

from sklearn.utils import shuffle
import shutil

for data in images_metadata:
    images_len = len(data["images"])
    train_len = round(images_len * 0.8)
    
    shuffled_images = shuffle(data["images"], random_state=0)
    
    train_images = shuffled_images[:train_len]
    val_images = shuffled_images[train_len:]
    
    assert len(train_images) + len(val_images) == images_len, "Problema no cálculo da quantidade de imagens de treino e teste!"
    
    for image_type in ["train", "val"]:
        
        if image_type == "train":
            path_to_save = data["train"]
            images_to_save = train_images
        else:
            path_to_save = data["val"]
            images_to_save = val_images
            
        image_folder_source = data["path"]
        
        for image_to_save in images_to_save:
            source_fullpath = os.path.join(image_folder_source, image_to_save)
            destiny_fullpath = os.path.join(path_to_save, image_to_save)
            
            shutil.copyfile(source_fullpath, destiny_fullpath)
    
    
#images_metadata

# %%
# Checando se não há nenhuma imagem repetida

for data in images_metadata:
    for image in os.listdir(data["train"]):
        assert not image in os.listdir(data["val"]), f"Imagem repetida encontrada! {image}"

# %%
# License: BSD
# Author: Sasank Chilamkurthy

from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'D:\\Kaio_Poc_Telhas\\FMD\\train_val_format'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

print(f'Dataset train len: {len(image_datasets["train"])}')
print(f'Dataset val len: {len(image_datasets["val"])}')

torch_version = "cuda:0" if torch.cuda.is_available() else "cpu"
print(f'Torch version: {torch_version}')
device = torch.device(torch_version)
# Out:
# Dataset train len: 800
# Dataset val len: 200
# Torch version: cuda:0

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
# model_ft.fc = nn.Linear(num_ftrs, 2)
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.9929 Acc: 0.3013
# val Loss: 1.4699 Acc: 0.5700
#
# Epoch 1/24
# ----------
# train Loss: 1.6512 Acc: 0.4600
# val Loss: 1.6261 Acc: 0.5750
#
# Epoch 2/24
# ----------
# train Loss: 1.4864 Acc: 0.5012
# val Loss: 1.7697 Acc: 0.5800
#
# Epoch 3/24
# ----------
# train Loss: 1.5525 Acc: 0.4888
# val Loss: 1.4943 Acc: 0.5850
#
# Epoch 4/24
# ----------
# train Loss: 1.4681 Acc: 0.5125
# val Loss: 1.6483 Acc: 0.5700
#
# Epoch 5/24
# ----------
# train Loss: 1.4352 Acc: 0.5525
# val Loss: 1.6869 Acc: 0.5800
#
# Epoch 6/24
# ----------
# train Loss: 1.3548 Acc: 0.5763
# val Loss: 1.5292 Acc: 0.6300
#
# Epoch 7/24
# ----------
# train Loss: 1.0427 Acc: 0.6625
# val Loss: 1.1702 Acc: 0.6850
#
# Epoch 8/24
# ----------
# train Loss: 0.8437 Acc: 0.7238
# val Loss: 1.1682 Acc: 0.6800
#
# Epoch 9/24
# ----------
# train Loss: 0.8482 Acc: 0.7263
# val Loss: 1.2023 Acc: 0.6800
#
# Epoch 10/24
# ----------
# train Loss: 0.8651 Acc: 0.7225
# val Loss: 1.1523 Acc: 0.6900
#
# Epoch 11/24
# ----------
# train Loss: 0.7450 Acc: 0.7450
# val Loss: 1.1282 Acc: 0.7200
#
# Epoch 12/24
# ----------
# train Loss: 0.7343 Acc: 0.7700
# val Loss: 1.1747 Acc: 0.7050
#
# Epoch 13/24
# ----------
# train Loss: 0.7180 Acc: 0.7738
# val Loss: 1.1465 Acc: 0.7450
#
# Epoch 14/24
# ----------
# train Loss: 0.7415 Acc: 0.7612
# val Loss: 1.1523 Acc: 0.7200
#
# Epoch 15/24
# ----------
# train Loss: 0.7352 Acc: 0.7625
# val Loss: 1.1762 Acc: 0.6950
#
# Epoch 16/24
# ----------
# train Loss: 0.6908 Acc: 0.7688
# val Loss: 1.1724 Acc: 0.6950
#
# Epoch 17/24
# ----------
# train Loss: 0.7024 Acc: 0.7788
# val Loss: 1.1895 Acc: 0.7050
#
# Epoch 18/24
# ----------
# train Loss: 0.6594 Acc: 0.7888
# val Loss: 1.1934 Acc: 0.7150
#
# Epoch 19/24
# ----------
# train Loss: 0.6536 Acc: 0.7938
# val Loss: 1.1641 Acc: 0.7300
#
# Epoch 20/24
# ----------
# train Loss: 0.7119 Acc: 0.7600
# val Loss: 1.1959 Acc: 0.7100
#
# Epoch 21/24
# ----------
# train Loss: 0.7063 Acc: 0.7788
# val Loss: 1.2204 Acc: 0.7150
#
# Epoch 22/24
# ----------
# train Loss: 0.7701 Acc: 0.7675
# val Loss: 1.1608 Acc: 0.7200
#
# Epoch 23/24
# ----------
# train Loss: 0.6317 Acc: 0.8050
# val Loss: 1.1781 Acc: 0.6950
#
# Epoch 24/24
# ----------
# train Loss: 0.7392 Acc: 0.7625
# val Loss: 1.1703 Acc: 0.7100
#
# Training complete in 8m 4s
# Best val Acc: 0.745000

# %%
visualize_model(model_ft)

# %%
# ConvNet as fixed feature extractor

# %%
model_conv = torchvision.models.resnet18(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, len(class_names))

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv, exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 2.0277 Acc: 0.3025
# val Loss: 1.1510 Acc: 0.6450
#
# Epoch 1/24
# ----------
# train Loss: 1.4966 Acc: 0.4913
# val Loss: 1.0585 Acc: 0.6750
#
# Epoch 2/24
# ----------
# train Loss: 1.3307 Acc: 0.5487
# val Loss: 1.1409 Acc: 0.6500
#
# Epoch 3/24
# ----------
# train Loss: 1.3943 Acc: 0.5388
# val Loss: 1.1135 Acc: 0.6950
#
# Epoch 4/24
# ----------
# train Loss: 1.2456 Acc: 0.5575
# val Loss: 1.0397 Acc: 0.6950
#
# Epoch 5/24
# ----------
# train Loss: 1.3193 Acc: 0.5687
# val Loss: 0.9703 Acc: 0.7450
#
# Epoch 6/24
# ----------
# train Loss: 1.1742 Acc: 0.5963
# val Loss: 1.0091 Acc: 0.6900
#
# Epoch 7/24
# ----------
# train Loss: 1.0916 Acc: 0.6412
# val Loss: 0.9135 Acc: 0.7350
#
# Epoch 8/24
# ----------
# train Loss: 1.0539 Acc: 0.6500
# val Loss: 0.9417 Acc: 0.7150
#
# Epoch 9/24
# ----------
# train Loss: 1.0415 Acc: 0.6512
# val Loss: 0.9003 Acc: 0.7600
#
# Epoch 10/24
# ----------
# train Loss: 1.0267 Acc: 0.6275
# val Loss: 0.9082 Acc: 0.7250
#
# Epoch 11/24
# ----------
# train Loss: 1.0770 Acc: 0.6325
# val Loss: 0.9365 Acc: 0.7400
#
# Epoch 12/24
# ----------
# train Loss: 1.0767 Acc: 0.6538
# val Loss: 0.9442 Acc: 0.7400
#
# Epoch 13/24
# ----------
# train Loss: 1.0621 Acc: 0.6300
# val Loss: 0.9505 Acc: 0.7250
#
# Epoch 14/24
# ----------
# train Loss: 1.0215 Acc: 0.6300
# val Loss: 0.9751 Acc: 0.7500
#
# Epoch 15/24
# ----------
# train Loss: 1.0081 Acc: 0.6638
# val Loss: 0.8938 Acc: 0.7300
#
# Epoch 16/24
# ----------
# train Loss: 1.0691 Acc: 0.6488
# val Loss: 0.9218 Acc: 0.7450
#
# Epoch 17/24
# ----------
# train Loss: 1.0812 Acc: 0.6412
# val Loss: 0.9286 Acc: 0.7250
#
# Epoch 18/24
# ----------
# train Loss: 1.0154 Acc: 0.6713
# val Loss: 0.9437 Acc: 0.7400
#
# Epoch 19/24
# ----------
# train Loss: 1.0765 Acc: 0.6512
# val Loss: 0.9254 Acc: 0.7200
#
# Epoch 20/24
# ----------
# train Loss: 1.0092 Acc: 0.6613
# val Loss: 0.9484 Acc: 0.7350
#
# Epoch 21/24
# ----------
# train Loss: 0.9863 Acc: 0.6688
# val Loss: 0.9487 Acc: 0.7350
#
# Epoch 22/24
# ----------
# train Loss: 1.0511 Acc: 0.6562
# val Loss: 0.9729 Acc: 0.7300
#
# Epoch 23/24
# ----------
# train Loss: 1.0005 Acc: 0.6575
# val Loss: 0.9037 Acc: 0.7450
#
# Epoch 24/24
# ----------
# train Loss: 1.0444 Acc: 0.6488
# val Loss: 0.9468 Acc: 0.7200
#
# Training complete in 7m 10s
# Best val Acc: 0.760000

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()
